# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 1732

# %%
import cv2

# %%
data_folder = r'\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear'

folders, fovs = ia.io_tools.data.get_folders(data_folder)
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 25
# - Number of field of views: 138

# %%
correction_folder = r'\\10.245.74.158\Chromatin_NAS_0\Corrections\20210621-Corrections_lumencor_from_60_to_50'

segmentation_save_folder = os.path.join(data_folder, 'Segmentation')
if not os.path.exists(segmentation_save_folder):
    os.makedirs(segmentation_save_folder)
from cellpose import models

from ImageAnalysis3.segmentation_tools.cell import Align_Segmentation
reload(ia.segmentation_tools.cell)

# transpose with microscope
microscope_file = r'\\mendel\pu_documents\Merfish_analysis\Merfish_Analysis_Scripts\merlin_parameters\microscope\storm6_microscope.json'
microscope_params = Align_Segmentation._read_microscope_json(microscope_file)
microscope_params
# Out:
# {'flip_horizontal': False,
#  'flip_vertical': True,
#  'transpose': True,
#  'microns_per_pixel': 0.108}

# %%
for _fov_id, _fov_name in enumerate(fovs):
    if _fov_id < 50:
        continue
    _save_id = _fov_id - 50    
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    print(f"- seg file: {seg_save_file}")
    if os.path.exists(seg_save_file):
        continue

    dapi_image_file = os.path.join(folders[0], _fov_name)
    polyt_image_file = os.path.join(folders[-1], _fov_name)
    print(dapi_image_file, polyt_image_file)
    # load reference DAPI
    _ref_cls = ia.classes.preprocess.DaxProcesser(dapi_image_file, 
                                                 CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _ref_cls._load_image(sel_channels=[488,405])
    _ref_cls._corr_illumination()
    _ref_im = _ref_cls.im_488[0::4]
    # load polyT
    _cls = ia.classes.preprocess.DaxProcesser(polyt_image_file, 
                                              CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _cls._load_image(sel_channels=[750,488])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._warp_image(corr_chromatic=False)
    # cellpose
    print(f"- apply microscope corrections")
    test_dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_ref_cls.im_405[0::4], microscope_params)
    test_polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_cls.im_750, microscope_params)
    
    print(f"- run Cellpose segmentation", end=' ')
    _cellpose_start = time.time()
    test_dapi_im = np.array([cv2.resize(_ly, (1024,1024) ) for _ly in test_dapi_im])
    test_polyt_im = np.array([cv2.resize(_ly, (1024,1024) ) for _ly in test_polyt_im])

    seg_model = models.CellposeModel(gpu=True, model_type='TN2')

    labels3d, _, _ = seg_model.eval(np.stack([test_polyt_im, test_dapi_im], axis=3), 
                                    batch_size=20, anisotropy=1000/108/2,
                                    cellprob_threshold=0, 
                                    channels=[1,2], 
                                    #diameter=25, 
                                    min_size=100,
                                    do_3D=True,
                                    )

    print(f"in {time.time()-_cellpose_start:.3f}s.")
    
    
    # resize segmentation label back
    corr_labels3d = np.array([cv2.resize(_ly, _cls.im_750.shape[1:], 
                                    interpolation=cv2.INTER_NEAREST_EXACT) 
                         for _ly in labels3d])

    
    print(corr_labels3d.shape, _fov_id, _save_id)
    # save this segmentation mask
    print(f"- save to file: {seg_save_file}")
    np.save(seg_save_file.split('.npy')[0], corr_labels3d, )
    #break
# Out:
# - seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_0.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_050.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_050.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_050.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.815s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.277s.
# -- corrected illumination for channel 405 in 4.308s.
# - Finished illumination correction in 8.776s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_050.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.243s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.119s.
# -- corrected illumination for channel 488 in 1.136s.
# - Finished illumination correction in 2.388s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02 -4.35 10.65] in 0.582s.
# -- drift 1: [-1.000e-02 -4.390e+00  1.058e+01] in 0.549s.
# -- drift 2: [ 0.   -4.43 10.74] in 0.552s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-1.00000000e-02 -4.39000000e+00  1.06566667e+01] for channel: 750
# -- finish warpping channel 750 in 16.290s.
# 488 False True
# -- warp image with drift:[-1.00000000e-02 -4.39000000e+00  1.06566667e+01] for channel: 488
# -- finish warpping channel 488 in 16.396s.
# -- finish warpping in 32.686s.
# - apply microscope corrections
# - run Cellpose segmentation in 35.813s.
# (13, 2048, 2048) 50 0
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_0.npy

# %% [markdown]
# ## Check result

# %%
visual_tools.imshow_mark_3d_v2([test_dapi_im, test_polyt_im, labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# # Run watershed

# %%
sys.path.append(r"..\..\MERlin")

import merlin
from merlin.util import watershed
from scipy import ndimage
from skimage import morphology
from skimage import segmentation

watershed_folder = os.path.join(segmentation_save_folder, 'watershed')
if not os.path.exists(watershed_folder):
    print(watershed_folder)
    os.makedirs(watershed_folder)

# %%
for _fov_id, _fov_name in enumerate(fovs):
    if _fov_id < 50:
        continue
    _save_id = _fov_id - 50    
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    watershed_save_file = os.path.join(watershed_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(watershed_save_file):
        continue
    
    print(f"- load seg file: {seg_save_file}")
    corr_labels3d = np.load(seg_save_file)
    
    dapi_image_file = os.path.join(folders[0], _fov_name)
    polyt_image_file = os.path.join(folders[-1], _fov_name)
    print(dapi_image_file, polyt_image_file)
    # load reference DAPI
    _ref_cls = ia.classes.preprocess.DaxProcesser(dapi_image_file, 
                                                 CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _ref_cls._load_image(sel_channels=[488,405])
    _ref_cls._corr_illumination()
    _ref_im = _ref_cls.im_488[0::4]
    # load polyT
    _cls = ia.classes.preprocess.DaxProcesser(polyt_image_file, 
                                              CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _cls._load_image(sel_channels=[750,488])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._warp_image(corr_chromatic=False)
    polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_cls.im_750, microscope_params)
    # Prepare watershed
    waterIm, waterMask = watershed.prepare_watershed_images(polyt_im, 1.5)
    waterMask[corr_labels3d > 0] = True
    # watershed
    new_labels = segmentation.watershed(
                    waterIm, corr_labels3d, mask=waterMask,
                    connectivity=np.ones((3, 3, 3)), watershed_line=True)
    new_labels = ndimage.grey_dilation(new_labels, structure=morphology.ball(1))
    # save
    # save this segmentation mask
    print(f"- save to file: {watershed_save_file}")
    np.save(watershed_save_file.split('.npy')[0], new_labels, )
# Out:
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_1.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_051.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_051.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_051.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 2.364s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 5.213s.
# -- corrected illumination for channel 405 in 5.005s.
# - Finished illumination correction in 10.241s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_051.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.470s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.341s.
# -- corrected illumination for channel 488 in 1.258s.
# - Finished illumination correction in 2.620s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 1.00e-02 -4.86e+00  1.48e+01] in 0.619s.
# -- drift 1: [ 1.000e-02 -4.730e+00  1.456e+01] in 0.693s.
# -- drift 2: [ 1.000e-02 -4.830e+00  1.485e+01] in 0.654s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 1.00000000e-02 -4.80666667e+00  1.47366667e+01] for channel: 750
# -- finish warpping channel 750 in 16.385s.
# 488 False True
# -- warp image with drift:[ 1.00000000e-02 -4.80666667e+00  1.47366667e+01] for channel: 488
# -- finish warpping channel 488 in 16.526s.
# -- finish warpping in 32.911s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_1.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_2.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_052.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_052.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_052.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 9.189s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.616s.
# -- corrected illumination for channel 405 in 4.498s.
# - Finished illumination correction in 9.300s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_052.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.198s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.110s.
# -- corrected illumination for channel 488 in 1.109s.
# - Finished illumination correction in 2.274s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.02 -6.1  13.69] in 0.585s.
# -- drift 1: [ 0.02 -6.27 13.54] in 0.588s.
# -- drift 2: [ 0.02 -6.05 13.96] in 0.573s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 0.02 -6.14 13.73] for channel: 750
# -- finish warpping channel 750 in 16.274s.
# 488 False True
# -- warp image with drift:[ 0.02 -6.14 13.73] for channel: 488
# -- finish warpping channel 488 in 16.344s.
# -- finish warpping in 32.619s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_2.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_3.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_053.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_053.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_053.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.963s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.233s.
# -- corrected illumination for channel 405 in 4.270s.
# - Finished illumination correction in 8.619s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_053.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.192s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.104s.
# -- corrected illumination for channel 488 in 1.139s.
# - Finished illumination correction in 2.301s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-1.000e-02 -4.820e+00  1.388e+01] in 0.613s.
# -- drift 1: [-0.02 -4.6  14.14] in 0.571s.
# -- drift 2: [-0.03 -4.61 14.23] in 0.586s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.02       -4.67666667 14.08333333] for channel: 750
# -- finish warpping channel 750 in 16.434s.
# 488 False True
# -- warp image with drift:[-0.02       -4.67666667 14.08333333] for channel: 488
# -- finish warpping channel 488 in 16.370s.
# -- finish warpping in 32.804s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_3.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_4.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_054.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_054.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_054.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.857s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.241s.
# -- corrected illumination for channel 405 in 4.270s.
# - Finished illumination correction in 8.625s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_054.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.260s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.126s.
# -- corrected illumination for channel 488 in 1.123s.
# - Finished illumination correction in 2.314s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.03  -2.94 -21.74] in 0.570s.
# -- drift 1: [-2.000e-02 -3.010e+00 -2.174e+01] in 0.572s.
# -- drift 2: [ -0.03  -2.78 -21.7 ] in 0.573s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ -0.02666667  -2.91       -21.72666667] for channel: 750
# -- finish warpping channel 750 in 16.339s.
# 488 False True
# -- warp image with drift:[ -0.02666667  -2.91       -21.72666667] for channel: 488
# -- finish warpping channel 488 in 16.496s.
# -- finish warpping in 32.835s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_4.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_5.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_055.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_055.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_055.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.088s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.255s.
# -- corrected illumination for channel 405 in 4.277s.
# - Finished illumination correction in 8.683s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_055.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.122s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.110s.
# -- corrected illumination for channel 488 in 1.121s.
# - Finished illumination correction in 2.295s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-2.00e-02 -4.89e+00  2.97e+01] in 0.574s.
# -- drift 1: [-0.03 -4.75 29.85] in 0.559s.
# -- drift 2: [-2.000e-02 -4.840e+00  2.996e+01] in 0.569s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-2.33333333e-02 -4.82666667e+00  2.98366667e+01] for channel: 750
# -- finish warpping channel 750 in 16.364s.
# 488 False True
# -- warp image with drift:[-2.33333333e-02 -4.82666667e+00  2.98366667e+01] for channel: 488
# -- finish warpping channel 488 in 16.560s.
# -- finish warpping in 32.924s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_5.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_6.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_056.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_056.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_056.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.978s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.318s.
# -- corrected illumination for channel 405 in 4.320s.
# - Finished illumination correction in 8.756s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_056.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.291s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.166s.
# -- corrected illumination for channel 488 in 1.134s.
# - Finished illumination correction in 2.413s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01 -4.68  4.95] in 0.600s.
# -- drift 1: [-0.01 -4.78  4.95] in 0.593s.
# -- drift 2: [ 0.   -4.81  5.01] in 0.648s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.00666667 -4.75666667  4.97      ] for channel: 750
# -- finish warpping channel 750 in 16.778s.
# 488 False True
# -- warp image with drift:[-0.00666667 -4.75666667  4.97      ] for channel: 488
# -- finish warpping channel 488 in 16.357s.
# -- finish warpping in 33.136s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_6.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_7.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_057.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_057.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_057.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.124s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.780s.
# -- corrected illumination for channel 405 in 4.521s.
# - Finished illumination correction in 9.372s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_057.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.189s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.102s.
# -- corrected illumination for channel 488 in 1.112s.
# - Finished illumination correction in 2.234s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -4.78 14.99] in 0.555s.
# -- drift 1: [ 0.   -4.86 14.83] in 0.556s.
# -- drift 2: [ 0.   -4.79 14.98] in 0.554s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 0.         -4.81       14.93333333] for channel: 750
# -- finish warpping channel 750 in 16.342s.
# 488 False True
# -- warp image with drift:[ 0.         -4.81       14.93333333] for channel: 488
# -- finish warpping channel 488 in 16.337s.
# -- finish warpping in 32.680s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_7.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_8.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_058.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_058.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_058.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.852s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.497s.
# -- corrected illumination for channel 405 in 4.495s.
# - Finished illumination correction in 9.121s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_058.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.123s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.110s.
# -- corrected illumination for channel 488 in 1.213s.
# - Finished illumination correction in 2.443s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -4.12  7.08] in 0.573s.
# -- drift 1: [ 0.01 -4.42  7.01] in 0.575s.
# -- drift 2: [ 0.01 -4.62  7.2 ] in 0.597s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 6.66666667e-03 -4.38666667e+00  7.09666667e+00] for channel: 750
# -- finish warpping channel 750 in 16.334s.
# 488 False True
# -- warp image with drift:[ 6.66666667e-03 -4.38666667e+00  7.09666667e+00] for channel: 488
# -- finish warpping channel 488 in 16.335s.
# -- finish warpping in 32.671s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_8.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_9.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_059.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_059.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_059.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.178s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.236s.
# -- corrected illumination for channel 405 in 4.282s.
# - Finished illumination correction in 8.638s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_059.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.238s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.111s.
# -- corrected illumination for channel 488 in 1.120s.
# - Finished illumination correction in 2.296s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -4.55  9.64] in 0.574s.
# -- drift 1: [ 0.   -4.69  9.26] in 0.565s.
# -- drift 2: [ 0.   -4.57  9.5 ] in 0.591s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 0.         -4.60333333  9.46666667] for channel: 750
# -- finish warpping channel 750 in 16.383s.
# 488 False True
# -- warp image with drift:[ 0.         -4.60333333  9.46666667] for channel: 488
# -- finish warpping channel 488 in 16.328s.
# -- finish warpping in 32.711s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_9.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_10.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_060.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_060.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_060.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.875s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.270s.
# -- corrected illumination for channel 405 in 4.269s.
# - Finished illumination correction in 8.636s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_060.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.200s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.112s.
# -- corrected illumination for channel 488 in 1.122s.
# - Finished illumination correction in 2.311s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02 -6.94 12.7 ] in 0.559s.
# -- drift 1: [-0.02 -7.19 12.57] in 0.585s.
# -- drift 2: [-1.000e-02 -7.220e+00  1.277e+01] in 0.573s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.01666667 -7.11666667 12.68      ] for channel: 750
# -- finish warpping channel 750 in 16.440s.
# 488 False True
# -- warp image with drift:[-0.01666667 -7.11666667 12.68      ] for channel: 488
# -- finish warpping channel 488 in 16.838s.
# -- finish warpping in 33.279s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_10.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_11.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_061.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_061.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_061.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 8.030s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.402s.
# -- corrected illumination for channel 405 in 4.663s.
# - Finished illumination correction in 9.161s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_061.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.237s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.243s.
# -- corrected illumination for channel 488 in 1.122s.
# - Finished illumination correction in 2.477s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.03 -2.49 15.6 ] in 0.664s.
# -- drift 1: [-0.06 -2.84 15.8 ] in 0.629s.
# -- drift 2: [-0.04 -2.68 15.8 ] in 0.656s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.04333333 -2.67       15.73333333] for channel: 750
# -- finish warpping channel 750 in 16.641s.
# 488 False True
# -- warp image with drift:[-0.04333333 -2.67       15.73333333] for channel: 488
# -- finish warpping channel 488 in 16.362s.
# -- finish warpping in 33.004s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_11.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_12.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_062.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_062.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_062.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.970s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.502s.
# -- corrected illumination for channel 405 in 4.504s.
# - Finished illumination correction in 9.080s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_062.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.257s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.106s.
# -- corrected illumination for channel 488 in 1.125s.
# - Finished illumination correction in 2.297s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.02 -5.44 19.92] in 0.652s.
# -- drift 1: [ 0.03 -5.41 19.94] in 0.625s.
# -- drift 2: [ 0.03 -5.53 20.1 ] in 0.570s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 0.02666667 -5.46       19.98666667] for channel: 750
# -- finish warpping channel 750 in 16.289s.
# 488 False True
# -- warp image with drift:[ 0.02666667 -5.46       19.98666667] for channel: 488
# -- finish warpping channel 488 in 16.415s.
# -- finish warpping in 32.704s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_12.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_13.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_063.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_063.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_063.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.270s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.425s.
# -- corrected illumination for channel 405 in 4.505s.
# - Finished illumination correction in 9.050s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_063.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.208s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.113s.
# -- corrected illumination for channel 488 in 1.117s.
# - Finished illumination correction in 2.295s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -5.11 12.84] in 0.581s.
# -- drift 1: [ 1.000e-02 -5.240e+00  1.287e+01] in 0.591s.
# -- drift 2: [ 0.   -5.11 13.16] in 0.569s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 3.33333333e-03 -5.15333333e+00  1.29566667e+01] for channel: 750
# -- finish warpping channel 750 in 16.322s.
# 488 False True
# -- warp image with drift:[ 3.33333333e-03 -5.15333333e+00  1.29566667e+01] for channel: 488
# -- finish warpping channel 488 in 16.321s.
# -- finish warpping in 32.644s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_13.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_14.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_064.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_064.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_064.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.021s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.508s.
# -- corrected illumination for channel 405 in 4.260s.
# - Finished illumination correction in 8.866s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_064.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.242s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.114s.
# -- corrected illumination for channel 488 in 1.131s.
# - Finished illumination correction in 2.311s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.03 -6.32 10.67] in 0.555s.
# -- drift 1: [-0.04 -6.39 10.7 ] in 0.581s.
# -- drift 2: [-0.03 -6.34 10.76] in 0.576s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.03333333 -6.35       10.71      ] for channel: 750
# -- finish warpping channel 750 in 16.345s.
# 488 False True
# -- warp image with drift:[-0.03333333 -6.35       10.71      ] for channel: 488
# -- finish warpping channel 488 in 16.311s.
# -- finish warpping in 32.657s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_14.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_15.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_065.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_065.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_065.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.741s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.267s.
# -- corrected illumination for channel 405 in 4.257s.
# - Finished illumination correction in 8.637s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_065.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.154s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.115s.
# -- corrected illumination for channel 488 in 1.118s.
# - Finished illumination correction in 2.311s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-1.000e-02 -3.180e+00  1.105e+01] in 0.584s.
# -- drift 1: [ 0.   -3.34 11.08] in 0.600s.
# -- drift 2: [-1.000e-02 -3.150e+00  1.117e+01] in 0.616s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-6.66666667e-03 -3.22333333e+00  1.11000000e+01] for channel: 750
# -- finish warpping channel 750 in 16.283s.
# 488 False True
# -- warp image with drift:[-6.66666667e-03 -3.22333333e+00  1.11000000e+01] for channel: 488
# -- finish warpping channel 488 in 16.361s.
# -- finish warpping in 32.645s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_15.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_16.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_066.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_066.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_066.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.024s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.224s.
# -- corrected illumination for channel 405 in 4.244s.
# - Finished illumination correction in 8.580s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_066.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.184s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.124s.
# -- corrected illumination for channel 488 in 1.126s.
# - Finished illumination correction in 2.321s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.04 -5.88 12.28] in 0.570s.
# -- drift 1: [ 0.05 -6.08 12.22] in 0.571s.
# -- drift 2: [ 0.04 -6.13 12.35] in 0.592s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 0.04333333 -6.03       12.28333333] for channel: 750
# -- finish warpping channel 750 in 16.986s.
# 488 False True
# -- warp image with drift:[ 0.04333333 -6.03       12.28333333] for channel: 488
# -- finish warpping channel 488 in 17.052s.
# -- finish warpping in 34.038s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_16.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_17.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_067.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_067.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_067.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.269s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.306s.
# -- corrected illumination for channel 405 in 4.464s.
# - Finished illumination correction in 8.912s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_067.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 3.560s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.291s.
# -- corrected illumination for channel 488 in 1.279s.
# - Finished illumination correction in 2.626s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.01 -4.17  6.52] in 0.585s.
# -- drift 1: [ 0.01 -4.21  6.74] in 0.623s.
# -- drift 2: [ 0.02 -4.2   6.74] in 0.615s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 0.01333333 -4.19333333  6.66666667] for channel: 750
# -- finish warpping channel 750 in 16.685s.
# 488 False True
# -- warp image with drift:[ 0.01333333 -4.19333333  6.66666667] for channel: 488
# -- finish warpping channel 488 in 16.306s.
# -- finish warpping in 32.993s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_17.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_18.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_068.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_068.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_068.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.956s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.662s.
# -- corrected illumination for channel 405 in 4.703s.
# - Finished illumination correction in 9.393s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_068.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.231s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.115s.
# -- corrected illumination for channel 488 in 1.117s.
# - Finished illumination correction in 2.250s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -4.64 16.41] in 0.561s.
# -- drift 1: [-1.000e-02 -4.550e+00  1.618e+01] in 0.579s.
# -- drift 2: [-1.00e-02 -4.50e+00  1.64e+01] in 0.575s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-6.66666667e-03 -4.56333333e+00  1.63300000e+01] for channel: 750
# -- finish warpping channel 750 in 16.356s.
# 488 False True
# -- warp image with drift:[-6.66666667e-03 -4.56333333e+00  1.63300000e+01] for channel: 488
# -- finish warpping channel 488 in 16.307s.
# -- finish warpping in 32.663s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_18.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_19.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_069.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_069.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_069.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.956s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.478s.
# -- corrected illumination for channel 405 in 4.557s.
# - Finished illumination correction in 9.103s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_069.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.200s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.144s.
# -- corrected illumination for channel 488 in 1.130s.
# - Finished illumination correction in 2.331s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-1.000e-02 -4.310e+00  1.015e+01] in 0.578s.
# -- drift 1: [-0.02 -4.68 10.05] in 0.578s.
# -- drift 2: [-0.02 -4.53 10.16] in 0.574s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.01666667 -4.50666667 10.12      ] for channel: 750
# -- finish warpping channel 750 in 16.232s.
# 488 False True
# -- warp image with drift:[-0.01666667 -4.50666667 10.12      ] for channel: 488
# -- finish warpping channel 488 in 16.383s.
# -- finish warpping in 32.615s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_19.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_20.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_070.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_070.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_070.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.858s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.453s.
# -- corrected illumination for channel 405 in 4.524s.
# - Finished illumination correction in 9.169s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_070.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.204s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.124s.
# -- corrected illumination for channel 488 in 1.112s.
# - Finished illumination correction in 2.356s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-1.00e-02 -5.59e+00  1.88e+01] in 0.587s.
# -- drift 1: [-1.000e-02 -5.630e+00  1.861e+01] in 0.550s.
# -- drift 2: [-0.02 -5.57 18.8 ] in 0.584s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-1.33333333e-02 -5.59666667e+00  1.87366667e+01] for channel: 750
# -- finish warpping channel 750 in 16.385s.
# 488 False True
# -- warp image with drift:[-1.33333333e-02 -5.59666667e+00  1.87366667e+01] for channel: 488
# -- finish warpping channel 488 in 16.346s.
# -- finish warpping in 32.731s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_20.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_21.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_071.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_071.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_071.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.153s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# ...
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.364s.
# -- corrected illumination for channel 405 in 4.337s.
# - Finished illumination correction in 8.833s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_131.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.450s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.089s.
# -- corrected illumination for channel 488 in 1.129s.
# - Finished illumination correction in 2.517s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.04 -3.94 14.17] in 0.552s.
# -- drift 1: [-0.03 -3.96 14.23] in 0.580s.
# -- drift 2: [-0.02 -3.92 14.24] in 0.549s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.03       -3.94       14.21333333] for channel: 750
# -- finish warpping channel 750 in 16.274s.
# 488 False True
# -- warp image with drift:[-0.03       -3.94       14.21333333] for channel: 488
# -- finish warpping channel 488 in 16.389s.
# -- finish warpping in 32.664s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_81.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_82.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_132.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_132.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_132.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.052s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.276s.
# -- corrected illumination for channel 405 in 4.266s.
# - Finished illumination correction in 8.683s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_132.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.162s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.106s.
# -- corrected illumination for channel 488 in 1.162s.
# - Finished illumination correction in 2.369s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02 -4.63 15.87] in 0.597s.
# -- drift 1: [-0.03 -4.69 15.92] in 0.542s.
# -- drift 2: [-0.02 -4.63 15.9 ] in 0.552s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.02333333 -4.65       15.89666667] for channel: 750
# -- finish warpping channel 750 in 16.342s.
# 488 False True
# -- warp image with drift:[-0.02333333 -4.65       15.89666667] for channel: 488
# -- finish warpping channel 488 in 16.328s.
# -- finish warpping in 32.671s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_82.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_83.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_133.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_133.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_133.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.127s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.274s.
# -- corrected illumination for channel 405 in 4.280s.
# - Finished illumination correction in 8.673s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_133.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.133s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.084s.
# -- corrected illumination for channel 488 in 1.113s.
# - Finished illumination correction in 2.257s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.06 -4.64  4.36] in 0.556s.
# -- drift 1: [-0.06 -4.64  4.52] in 0.611s.
# -- drift 2: [-0.09 -4.64  4.48] in 0.560s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.07       -4.64        4.45333333] for channel: 750
# -- finish warpping channel 750 in 16.310s.
# 488 False True
# -- warp image with drift:[-0.07       -4.64        4.45333333] for channel: 488
# -- finish warpping channel 488 in 16.348s.
# -- finish warpping in 32.659s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_83.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_84.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_134.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_134.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_134.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.794s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.288s.
# -- corrected illumination for channel 405 in 4.310s.
# - Finished illumination correction in 8.711s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_134.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.191s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.099s.
# -- corrected illumination for channel 488 in 1.124s.
# - Finished illumination correction in 2.337s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.03 -4.58 13.16] in 0.598s.
# -- drift 1: [-1.000e-02 -4.740e+00  1.313e+01] in 0.577s.
# -- drift 2: [-1.000e-02 -4.770e+00  1.319e+01] in 0.568s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.01666667 -4.69666667 13.16      ] for channel: 750
# -- finish warpping channel 750 in 16.264s.
# 488 False True
# -- warp image with drift:[-0.01666667 -4.69666667 13.16      ] for channel: 488
# -- finish warpping channel 488 in 16.427s.
# -- finish warpping in 32.691s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_84.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_85.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_135.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_135.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_135.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 7.931s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.286s.
# -- corrected illumination for channel 405 in 4.281s.
# - Finished illumination correction in 8.687s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_135.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.263s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.106s.
# -- corrected illumination for channel 488 in 1.190s.
# - Finished illumination correction in 2.353s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-1.000e-02 -4.190e+00  2.176e+01] in 0.541s.
# -- drift 1: [-2.000e-02 -4.320e+00  2.175e+01] in 0.615s.
# -- drift 2: [-0.03 -4.44 21.93] in 0.555s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-2.00000000e-02 -4.31666667e+00  2.18133333e+01] for channel: 750
# -- finish warpping channel 750 in 16.342s.
# 488 False True
# -- warp image with drift:[-2.00000000e-02 -4.31666667e+00  2.18133333e+01] for channel: 488
# -- finish warpping channel 488 in 16.575s.
# -- finish warpping in 32.917s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_85.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_86.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_136.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_136.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_136.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 7.090s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.259s.
# -- corrected illumination for channel 405 in 4.308s.
# - Finished illumination correction in 8.732s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_136.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.154s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.096s.
# -- corrected illumination for channel 488 in 1.127s.
# - Finished illumination correction in 2.307s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-2.000e-02 -6.470e+00  2.056e+01] in 0.559s.
# -- drift 1: [-1.000e-02 -6.550e+00  2.062e+01] in 0.571s.
# -- drift 2: [-1.000e-02 -6.520e+00  2.078e+01] in 0.605s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-1.33333333e-02 -6.51333333e+00  2.06533333e+01] for channel: 750
# -- finish warpping channel 750 in 16.340s.
# 488 False True
# -- warp image with drift:[-1.33333333e-02 -6.51333333e+00  2.06533333e+01] for channel: 488
# -- finish warpping channel 488 in 16.672s.
# -- finish warpping in 33.014s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_86.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\segmentation_label_87.npy
# \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_137.dax \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_137.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H0M1\Conv_zscan_137.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 10.460s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 4.276s.
# -- corrected illumination for channel 405 in 4.260s.
# - Finished illumination correction in 8.752s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\H24M25\Conv_zscan_137.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.267s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.161s.
# -- corrected illumination for channel 488 in 1.131s.
# - Finished illumination correction in 2.374s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02 -4.82 15.8 ] in 0.572s.
# -- drift 1: [ 0.   -4.86 15.72] in 0.553s.
# -- drift 2: [-0.04 -4.84 15.92] in 0.580s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.02       -4.84       15.81333333] for channel: 750
# -- finish warpping channel 750 in 16.348s.
# 488 False True
# -- warp image with drift:[-0.02       -4.84       15.81333333] for channel: 488
# -- finish warpping channel 488 in 16.738s.
# -- finish warpping in 33.087s.
# - save to file: \\10.245.74.158\Chromatin_NAS_6\20220525-hSTG0308_250gene_noclear\Segmentation\watershed\segmentation_label_87.npy

# %%
from scipy import ndimage

# %%
visual_tools.imshow_mark_3d_v2([polyt_im, waterIm, waterMask, corr_labels3d, new_labels])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# # check merlin outputs

# %%
import h5py

# %%
merlin_feature_file = r'\\mendel\Mendel_SSD3\MERFISH_Analysis\20220525-hSTG_test\CellPoseSegment\features\feature_data_0.hdf5'
with h5py.File(merlin_feature_file, 'r') as _f:
    print(_f['labeldata'].keys())
    watershed_labels = _f['labeldata']['label3D'][:]
# Out:
# <KeysViewHDF5 ['label3D']>

# %%
visual_tools.imshow_mark_3d_v2([watershed_labels])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
merlin_feature_file = r'\\mendel\Mendel_SSD3\MERFISH_Analysis\20220525-hSTG\CellPoseSegment\features\feature_data_80.hdf5'
with h5py.File(merlin_feature_file, 'r') as _f:
    print(_f['labeldata'].keys())
    new_watershed_labels = _f['labeldata']['label3D'][:]
# Out:
# <KeysViewHDF5 ['label3D']>

# %%
from skimage import segmentation

new_labels = segmentation.watershed(
                waterIm, old_label3d, mask=waterMask,
                connectivity=np.ones((3, 3, 3)), watershed_line=True)

# %%
visual_tools.imshow_mark_3d_v2([polyt_im, waterIm, waterMask, old_label3d, new_labels])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
relabel_info = pickle.load(open(r'E:\Processed_Data_Backup\202003_IMR90_chr2_repeat_relabelling\picked_relabeled_spot_pairs_2-71.pkl','rb'))

# %%
visual_tools

# %%
relabe_zxys
# Out:
# array([[[2.44868031e+03, 4.69997054e+03, 7.23436359e+03, 7.48437071e+00],
#         [3.73104439e+03, 4.62864729e+03, 7.40921924e+03, 2.39197063e+00],
#         [2.24792957e+03, 4.69036958e+03, 7.14845435e+03, 1.58881152e+00],
#         ...,
#         [2.64051418e+03, 3.11798666e+03, 6.11022821e+03, 9.19883347e+00],
#         [2.63617077e+03, 3.07044704e+03, 6.22241441e+03, 7.41383934e+00],
#         [2.26103153e+03, 3.21625182e+03, 6.25290601e+03, 3.86180091e+00]],
#
#        [[2.16445065e+03, 3.13107282e+03, 1.01894727e+04, 8.00683212e+00],
#         [3.10189037e+03, 4.85165479e+03, 1.02543698e+04, 5.19267321e+00],
#         [2.81243649e+03, 4.97361086e+03, 1.03899894e+04, 2.71444392e+00],
#         ...,
#         [2.79996834e+03, 3.67189906e+03, 1.06949391e+04, 2.33186173e+00],
#         [2.76656399e+03, 3.55870226e+03, 1.10467400e+04, 4.68488646e+00],
#         [2.73376083e+03, 3.81614900e+03, 1.05940896e+04, 1.11110854e+00]],
#
#        [[2.97902107e+03, 1.35271961e+04, 9.24907709e+03, 2.12193418e+00],
#         [2.62704201e+03, 1.57878743e+04, 9.23451334e+03, 7.00704765e+00],
#         [2.79477100e+03, 1.35925439e+04, 1.01560342e+04, 1.01266706e+00],
#         ...,
#         [           nan,            nan,            nan,            nan],
#         [3.10226517e+03, 1.45113893e+04, 9.66864743e+03, 8.34150791e+00],
#         [2.80726833e+03, 1.26279992e+04, 9.91077402e+03, 1.07415056e+00]],
#
#        ...,
#
#        [[3.35780334e+03, 1.32524129e+04, 1.19542830e+04, 7.17778301e+00],
#         [3.21805115e+03, 1.35163172e+04, 1.17506681e+04, 3.82557464e+00],
#         [3.99668999e+03, 1.41176019e+04, 1.10253851e+04, 1.02301371e+00],
#         ...,
#         [2.27467670e+03, 1.54966783e+04, 9.50054507e+03, 2.29083395e+00],
#         [           nan,            nan,            nan,            nan],
#         [3.21372871e+03, 1.38399027e+04, 9.72741000e+03, 1.20238936e+00]],
#
#        [[4.40048752e+03, 1.03669124e+04, 9.61956244e+03, 3.40483308e+00],
#         [4.23235359e+03, 1.03134702e+04, 1.01139348e+04, 6.66431713e+00],
#         [4.37509918e+03, 1.01326646e+04, 9.93950601e+03, 1.74417841e+00],
#         ...,
#         [3.36371765e+03, 1.10652177e+04, 9.59894989e+03, 8.15124798e+00],
#         [3.36422920e+03, 1.10779176e+04, 9.83741061e+03, 2.77450657e+00],
#         [3.40546494e+03, 1.12866073e+04, 9.75869632e+03, 3.03960609e+00]],
#
#        [[4.55858154e+03, 7.71181979e+03, 1.01457370e+04, 4.62582684e+00],
#         [4.35358238e+03, 7.41166562e+03, 1.03649983e+04, 2.49684477e+00],
#         [4.20474014e+03, 7.59263763e+03, 1.02324422e+04, 4.17591000e+00],
#         ...,
#         [3.58485298e+03, 6.72820999e+03, 1.20544774e+04, 2.03035903e+00],
#         [3.28166542e+03, 6.44165923e+03, 1.19039546e+04, 7.73473501e+00],
#         [3.84789696e+03, 6.28904677e+03, 1.18921709e+04, 1.17831554e+01]]])

# %%
relabe_zxys = np.load(r'\\10.245.74.158\Chromatin_NAS_4\2020_cell_materials\Chromatin_Share\Repicked_chromosome_data\before_20200512\zxyhs_final_EM_chr21_relabel.npy')

# %%
relabel_info['old'][1][0]
# Out:
# array([[ 0.00000000e+00,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        [ 0.00000000e+00,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        [ 1.88830070e+01,  2.29775448e+01,  1.74338776e+02, ...,
#         -6.78960886e-03, -6.34057760e-01,  5.79653076e+02],
#        ...,
#        [ 2.60387554e+01,  2.41951199e+01,  1.68056412e+02, ...,
#          1.13709886e-02,  8.33605453e-02,  6.47226807e+02],
#        [ 4.13785648e+00,  2.30000000e+01,  1.66000000e+02, ...,
#          2.44903816e-07,  4.09684958e-07,  4.69725189e+02],
#        [ 1.32260017e+01,  2.31380005e+01,  1.71030380e+02, ...,
#          4.81985718e-01, -4.74240720e-01,  3.35760864e+02]])

# %%
len(relabel_info['old'][1][0])
# Out:
# 357

# %%
len(relabel_info['new'][0][0])
# Out:
# 357

# %%
# !dir ..\..\S
# Out:
#  Volume in drive E is Data_01
#  Volume Serial Number is B8F1-585C
#
#  Directory of E:\Users\puzheng\Documents
#
# 05/28/2022  01:00 AM    <DIR>          .
# 05/28/2022  01:00 AM    <DIR>          ..
# 10/20/2020  12:30 AM    <DIR>          Chromatin_Analysis_2020_cell
# 05/26/2022  04:03 PM    <DIR>          Chromatin_Analysis_Scripts
# 10/20/2020  12:23 AM    <DIR>          Codes
# 05/26/2022  04:55 PM    <DIR>          ConvNeXt
# 10/20/2020  12:23 AM    <DIR>          Custom Office Templates
# 12/18/2020  10:12 PM             1,276 debug.log
# 10/20/2020  12:23 AM    <DIR>          dna-analysis
# 10/20/2020  12:23 AM    <DIR>          Hi-C
# 05/26/2022  03:09 PM    <DIR>          ImageAnalysis3
# 05/28/2022  01:00 AM    <DIR>          Insight3
# 05/27/2022  12:55 PM    <DIR>          Merfish_Analysis_Scripts
# 05/27/2022  12:55 PM    <DIR>          MERlin
# 05/26/2022  03:40 PM    <DIR>          OneNote Notebooks
# 05/26/2022  02:37 PM    <DIR>          Python Scripts
# 10/20/2020  12:23 AM    <DIR>          rdpwrap
# 09/30/2018  02:41 PM               407 Startup_linux.py
# 10/29/2018  01:13 PM               363 Startup_py3.py
# 05/26/2022  04:03 PM               117 Start_jupyter.bat
# 10/01/2018  09:40 PM               650 test_multiprocess.py
# 10/20/2020  12:23 AM    <DIR>          Visual Studio 2017
# 05/26/2022  05:01 PM    <DIR>          Visual Studio 2022
#                5 File(s)          2,813 bytes
#               18 Dir(s)  3,137,497,874,432 bytes free
