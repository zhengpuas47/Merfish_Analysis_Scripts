# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 19064

# %%
import cv2

# %%
data_folder = r'\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors'

folders, fovs = ia.io_tools.data.get_folders(data_folder)

dapi_image_file = os.path.join(data_folder, 'H0M1', 'Conv_zscan_001.dax')
#dapi_im = visual_tools.DaxReader(dapi_image_file).loadAll()[3::4][0::4]
#dapi_im = im[3::4]#[::4]
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 12
# - Number of field of views: 161

# %%
correction_folder = r'\\10.245.74.158\Chromatin_NAS_0\Corrections\20210621-Corrections_lumencor_from_60_to_50'

segmentation_save_folder = os.path.join(data_folder, 'Segmentation')
if not os.path.exists(segmentation_save_folder):
    os.makedirs(segmentation_save_folder)
from cellpose import models

from ImageAnalysis3.segmentation_tools.cell import Align_Segmentation
reload(ia.segmentation_tools.cell)

# transpose with microscope
microscope_file = r'\\mendel\pu_documents\Merfish_analysis\Merfish_Analysis_Scripts\merlin_parameters\microscope\storm6_microscope.json'
microscope_params = Align_Segmentation._read_microscope_json(microscope_file)
microscope_params
# Out:
# {'flip_horizontal': False,
#  'flip_vertical': True,
#  'transpose': True,
#  'microns_per_pixel': 0.108}

# %%
for _fov_id, _fov_name in enumerate(fovs):
    
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_fov_id}.npy')
    if os.path.exists(seg_save_file):
        continue

    dapi_image_file = os.path.join(folders[0], _fov_name)
    polyt_image_file = os.path.join(folders[-1], _fov_name)
    print(dapi_image_file, polyt_image_file)
    # load reference DAPI
    _ref_cls = ia.classes.preprocess.DaxProcesser(dapi_image_file, 
                                                 CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _ref_cls._load_image(sel_channels=[750,488,405])
    _ref_cls._corr_illumination()
    _ref_im = _ref_cls.im_488[0::4]
    # load polyT
    _cls = ia.classes.preprocess.DaxProcesser(polyt_image_file, 
                                              CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _cls._load_image(sel_channels=[750,488])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._warp_image(corr_chromatic=False)
    # cellpose
    print(f"- apply microscope corrections")
    test_dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_ref_cls.im_405[0::4], microscope_params)
    test_polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_cls.im_750, microscope_params)
    
    print(f"- run Cellpose segmentation", end=' ')
    _cellpose_start = time.time()
    test_dapi_im = np.array([cv2.resize(_ly, (1024,1024) ) for _ly in test_dapi_im])
    test_polyt_im = np.array([cv2.resize(_ly, (1024,1024) ) for _ly in test_polyt_im])

    seg_model = models.CellposeModel(gpu=True, model_type='TN2')

    labels3d, _, _ = seg_model.eval(np.stack([test_polyt_im, test_dapi_im], axis=3), 
                                    batch_size=20, anisotropy=1000/108/2,
                                    cellprob_threshold=0, 
                                    channels=[1,2], diameter=30, min_size=100,
                                    do_3D=True,
                                    )

    print(f"in {time.time()-_cellpose_start:.3f}s.")
    
    
    # resize segmentation label back
    labels3d = np.array([cv2.resize(_ly, _cls.im_750.shape[1:], 
                                    interpolation=cv2.INTER_NEAREST_EXACT) 
                         for _ly in labels3d])

    
    print(labels3d.shape, _fov_id)
    # save this segmentation mask
    print(f"- save to file: {seg_save_file}")
    np.save(seg_save_file.split('.npy')[0], labels3d, )

# %% [markdown]
# ## Check result

# %%
visual_tools.imshow_mark_3d_v2([_ref_cls.im_405, _cls.im_750, labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# ## Watershed

# %%
print(segmentation_save_folder)
# Out:
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation

# %%
sys.path.append(r"..\..\MERlin")

import merlin
from merlin.util import watershed
from scipy import ndimage
from skimage import morphology
from skimage import segmentation

watershed_folder = os.path.join(segmentation_save_folder, 'watershed')
if not os.path.exists(watershed_folder):
    print(watershed_folder)
    os.makedirs(watershed_folder)

# %%
for _fov_id, _fov_name in enumerate(fovs):
    
    _save_id = _fov_id
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    watershed_save_file = os.path.join(watershed_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(watershed_save_file):
        continue
    
    print(f"- load seg file: {seg_save_file}")
    corr_labels3d = np.load(seg_save_file).astype(np.int16)
    # load DAPI/polyT
    dapi_image_file = os.path.join(folders[0], _fov_name)
    polyt_image_file = os.path.join(folders[-1], _fov_name)
    print(dapi_image_file, polyt_image_file)
    # load reference DAPI
    _ref_cls = ia.classes.preprocess.DaxProcesser(dapi_image_file, 
                                                 CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _ref_cls._load_image(sel_channels=[488,405])
    _ref_cls._corr_illumination()
    _ref_im = _ref_cls.im_488[0::4]
    # load polyT
    _cls = ia.classes.preprocess.DaxProcesser(polyt_image_file, 
                                              CorrectionFolder=correction_folder, DriftChannel=488, DapiChannel=405)
    _cls._load_image(sel_channels=[750,488])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._warp_image(corr_chromatic=False)
    polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_cls.im_750, microscope_params)
    # Prepare watershed
    waterIm, waterMask = watershed.prepare_watershed_images(polyt_im, 1.5)
    waterMask[corr_labels3d > 0] = True
    waterMask = ndimage.binary_dilation(waterMask, structure=morphology.ball(1))
    # watershed
    new_labels = segmentation.watershed(
                    waterIm, corr_labels3d, mask=waterMask,
                    connectivity=np.ones((3, 3, 3)), watershed_line=True)
    # save this segmentation mask
    print(f"- save to file: {watershed_save_file}")
    np.save(watershed_save_file.split('.npy')[0], new_labels, )
# Out:
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_1.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_001.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_001.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_001.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 3.969s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.199s.
# -- corrected illumination for channel 405 in 8.485s.
# - Finished illumination correction in 16.826s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_001.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.815s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.984s.
# -- corrected illumination for channel 488 in 2.031s.
# - Finished illumination correction in 4.219s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.07 -8.36  3.01] in 0.844s.
# -- drift 1: [-0.1  -8.12  2.99] in 0.828s.
# -- drift 2: [-0.08 -8.04  3.15] in 0.798s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.08333333 -8.17333333  3.05      ] for channel: 750
# -- finish warpping channel 750 in 22.077s.
# 488 False True
# -- warp image with drift:[-0.08333333 -8.17333333  3.05      ] for channel: 488
# -- finish warpping channel 488 in 22.375s.
# -- finish warpping in 44.452s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_1.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_2.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_002.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_002.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_002.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.062s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 7.875s.
# -- corrected illumination for channel 405 in 8.094s.
# - Finished illumination correction in 16.203s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_002.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.842s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.042s.
# -- corrected illumination for channel 488 in 2.031s.
# - Finished illumination correction in 4.250s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.14 -12.33   2.19] in 0.859s.
# -- drift 1: [ -0.13 -12.12   2.32] in 0.828s.
# -- drift 2: [ -0.21 -12.21   2.28] in 0.812s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ -0.16       -12.22         2.26333333] for channel: 750
# -- finish warpping channel 750 in 22.141s.
# 488 False True
# -- warp image with drift:[ -0.16       -12.22         2.26333333] for channel: 488
# -- finish warpping channel 488 in 22.406s.
# -- finish warpping in 44.547s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_2.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_3.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_003.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_003.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_003.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.266s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.125s.
# -- corrected illumination for channel 405 in 8.344s.
# - Finished illumination correction in 16.641s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_003.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.906s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.125s.
# -- corrected illumination for channel 488 in 2.094s.
# - Finished illumination correction in 4.469s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.13 -8.45 -1.33] in 0.814s.
# -- drift 1: [ -0.37 -91.92 240.1 ] in 0.826s.
# -- drift 2: [-0.13 -8.46 -1.24] in 0.828s.
# -- drift 3: [-0.12 -8.54 -1.27] in 0.812s.
# -- drift 4: [-0.18 -8.41 -1.06] in 0.851s.
# -- drift 5: [-0.13 -8.45 -1.28] in 0.836s.
# -- drift 6: [-0.2  -8.55 -1.4 ] in 0.828s.
# -- drift 7: [-0.12 -8.37 -1.25] in 0.828s.
# -- return a sub-optimal drift
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.13       -8.45333333 -1.28333333] for channel: 750
# -- finish warpping channel 750 in 22.547s.
# 488 False True
# -- warp image with drift:[-0.13       -8.45333333 -1.28333333] for channel: 488
# -- finish warpping channel 488 in 22.656s.
# -- finish warpping in 45.203s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_3.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_4.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_004.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_004.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_004.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 3.938s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.359s.
# -- corrected illumination for channel 405 in 8.328s.
# - Finished illumination correction in 16.860s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_004.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.797s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.000s.
# -- corrected illumination for channel 488 in 2.031s.
# - Finished illumination correction in 4.313s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.05 -9.91  4.89] in 0.812s.
# -- drift 1: [-0.06 -9.92  5.16] in 0.828s.
# -- drift 2: [-0.06 -9.82  5.01] in 0.828s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.05666667 -9.88333333  5.02      ] for channel: 750
# -- finish warpping channel 750 in 22.422s.
# 488 False True
# -- warp image with drift:[-0.05666667 -9.88333333  5.02      ] for channel: 488
# -- finish warpping channel 488 in 22.797s.
# -- finish warpping in 45.219s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_4.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_5.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_005.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_005.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_005.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 4.265s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.047s.
# -- corrected illumination for channel 405 in 8.344s.
# - Finished illumination correction in 16.547s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_005.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.007s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.140s.
# -- corrected illumination for channel 488 in 2.031s.
# - Finished illumination correction in 4.359s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.07 -8.99  1.28] in 0.844s.
# -- drift 1: [-0.06 -9.    1.42] in 0.828s.
# -- drift 2: [-0.09 -8.76  1.25] in 0.844s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.07333333 -8.91666667  1.31666667] for channel: 750
# -- finish warpping channel 750 in 22.579s.
# 488 False True
# -- warp image with drift:[-0.07333333 -8.91666667  1.31666667] for channel: 488
# -- finish warpping channel 488 in 22.718s.
# -- finish warpping in 45.297s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_5.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_6.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_006.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_006.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_006.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.625s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.380s.
# -- corrected illumination for channel 405 in 9.965s.
# - Finished illumination correction in 18.525s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_006.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.078s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.755s.
# -- corrected illumination for channel 488 in 2.623s.
# - Finished illumination correction in 5.540s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.04 -6.79 -0.37] in 0.891s.
# -- drift 1: [-0.08 -6.7  -0.26] in 0.923s.
# -- drift 2: [-0.07 -6.62 -0.46] in 0.907s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.06333333 -6.70333333 -0.36333333] for channel: 750
# -- finish warpping channel 750 in 23.577s.
# 488 False True
# -- warp image with drift:[-0.06333333 -6.70333333 -0.36333333] for channel: 488
# -- finish warpping channel 488 in 23.281s.
# -- finish warpping in 46.858s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_6.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_7.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_007.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_007.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_007.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.234s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.016s.
# -- corrected illumination for channel 405 in 8.078s.
# - Finished illumination correction in 16.328s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_007.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.016s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 1.995s.
# -- corrected illumination for channel 488 in 2.078s.
# - Finished illumination correction in 4.313s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.04 -7.78  0.99] in 0.818s.
# -- drift 1: [-0.05 -7.79  1.14] in 0.807s.
# -- drift 2: [-0.05 -7.81  1.01] in 0.828s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.04666667 -7.79333333  1.04666667] for channel: 750
# -- finish warpping channel 750 in 22.453s.
# 488 False True
# -- warp image with drift:[-0.04666667 -7.79333333  1.04666667] for channel: 488
# -- finish warpping channel 488 in 22.927s.
# -- finish warpping in 45.380s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_7.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_8.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_008.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_008.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_008.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 4.922s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.038s.
# -- corrected illumination for channel 405 in 8.087s.
# - Finished illumination correction in 16.344s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_008.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 2.016s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.000s.
# -- corrected illumination for channel 488 in 2.063s.
# - Finished illumination correction in 4.406s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.04 -7.39 -4.59] in 0.828s.
# -- drift 1: [-0.07 -7.49 -5.35] in 0.828s.
# -- drift 2: [-0.09 -7.45 -5.24] in 0.828s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.06666667 -7.44333333 -5.06      ] for channel: 750
# -- finish warpping channel 750 in 22.953s.
# 488 False True
# -- warp image with drift:[-0.06666667 -7.44333333 -5.06      ] for channel: 488
# -- finish warpping channel 488 in 23.172s.
# -- finish warpping in 46.125s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_8.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_9.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_009.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_009.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_009.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.047s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.656s.
# -- corrected illumination for channel 405 in 8.453s.
# - Finished illumination correction in 17.281s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_009.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.859s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.156s.
# -- corrected illumination for channel 488 in 2.172s.
# - Finished illumination correction in 4.469s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.07 -8.34  0.79] in 0.875s.
# -- drift 1: [-0.05 -8.12  0.89] in 0.859s.
# -- drift 2: [-0.08 -8.11  0.86] in 0.828s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.06666667 -8.19        0.84666667] for channel: 750
# -- finish warpping channel 750 in 22.516s.
# 488 False True
# -- warp image with drift:[-0.06666667 -8.19        0.84666667] for channel: 488
# -- finish warpping channel 488 in 22.875s.
# -- finish warpping in 45.391s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_9.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_10.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_010.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_010.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_010.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.265s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.384s.
# -- corrected illumination for channel 405 in 8.328s.
# - Finished illumination correction in 16.875s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_010.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.797s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.562s.
# -- corrected illumination for channel 488 in 2.578s.
# - Finished illumination correction in 5.344s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.09 -13.66   0.35] in 0.921s.
# -- drift 1: [ -0.06 -13.44   0.61] in 0.891s.
# -- drift 2: [ -0.07 -13.26   0.61] in 0.859s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ -0.07333333 -13.45333333   0.52333333] for channel: 750
# -- finish warpping channel 750 in 23.453s.
# 488 False True
# -- warp image with drift:[ -0.07333333 -13.45333333   0.52333333] for channel: 488
# -- finish warpping channel 488 in 23.547s.
# -- finish warpping in 47.000s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_10.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_11.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_011.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_011.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_011.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 3.953s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.385s.
# -- corrected illumination for channel 405 in 8.219s.
# - Finished illumination correction in 16.875s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_011.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.171s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.078s.
# -- corrected illumination for channel 488 in 2.141s.
# - Finished illumination correction in 4.406s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.03 -7.7   2.09] in 0.844s.
# -- drift 1: [-0.02 -7.57  2.18] in 0.844s.
# -- drift 2: [-0.04 -7.64  2.12] in 0.859s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.03       -7.63666667  2.13      ] for channel: 750
# -- finish warpping channel 750 in 23.047s.
# 488 False True
# -- warp image with drift:[-0.03       -7.63666667  2.13      ] for channel: 488
# -- finish warpping channel 488 in 23.516s.
# -- finish warpping in 46.562s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_11.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_12.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_012.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_012.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_012.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 4.979s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.125s.
# -- corrected illumination for channel 405 in 8.375s.
# - Finished illumination correction in 16.687s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_012.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.828s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.245s.
# -- corrected illumination for channel 488 in 2.141s.
# - Finished illumination correction in 4.547s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.03 -10.65   2.31] in 0.859s.
# -- drift 1: [ -0.04 -10.42   2.26] in 0.828s.
# -- drift 2: [ -0.06 -10.57   2.36] in 0.828s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ -0.04333333 -10.54666667   2.31      ] for channel: 750
# -- finish warpping channel 750 in 22.953s.
# 488 False True
# -- warp image with drift:[ -0.04333333 -10.54666667   2.31      ] for channel: 488
# -- finish warpping channel 488 in 23.281s.
# -- finish warpping in 46.234s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_12.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_13.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_013.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_013.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_013.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 7.156s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.391s.
# -- corrected illumination for channel 405 in 8.331s.
# - Finished illumination correction in 16.970s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_013.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.062s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.141s.
# -- corrected illumination for channel 488 in 2.141s.
# - Finished illumination correction in 4.516s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.08 -10.45   1.18] in 0.844s.
# -- drift 1: [ -0.09 -10.52   1.4 ] in 0.844s.
# -- drift 2: [ -0.1  -10.44   1.21] in 0.845s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ -0.09       -10.47         1.26333333] for channel: 750
# -- finish warpping channel 750 in 22.920s.
# 488 False True
# -- warp image with drift:[ -0.09       -10.47         1.26333333] for channel: 488
# -- finish warpping channel 488 in 23.826s.
# -- finish warpping in 46.747s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_13.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_14.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_014.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_014.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_014.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 7.422s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 12.359s.
# -- corrected illumination for channel 405 in 10.547s.
# - Finished illumination correction in 23.219s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_014.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.844s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.219s.
# -- corrected illumination for channel 488 in 2.219s.
# - Finished illumination correction in 4.766s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.05 -8.7   0.24] in 0.875s.
# -- drift 1: [-0.06 -8.58  0.36] in 0.891s.
# -- drift 2: [-0.07 -8.67  0.28] in 0.891s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.06       -8.65        0.29333333] for channel: 750
# -- finish warpping channel 750 in 24.000s.
# 488 False True
# -- warp image with drift:[-0.06       -8.65        0.29333333] for channel: 488
# -- finish warpping channel 488 in 24.484s.
# -- finish warpping in 48.484s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_14.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_15.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_015.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_015.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_015.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.437s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.487s.
# -- corrected illumination for channel 405 in 8.778s.
# - Finished illumination correction in 17.719s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_015.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 2.391s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.250s.
# -- corrected illumination for channel 488 in 2.203s.
# - Finished illumination correction in 5.500s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.06 -8.96 -2.28] in 0.906s.
# -- drift 1: [-0.06 -8.71 -2.11] in 0.891s.
# -- drift 2: [-0.08 -8.82 -2.23] in 0.891s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.06666667 -8.83       -2.20666667] for channel: 750
# -- finish warpping channel 750 in 23.797s.
# 488 False True
# -- warp image with drift:[-0.06666667 -8.83       -2.20666667] for channel: 488
# -- finish warpping channel 488 in 24.094s.
# -- finish warpping in 47.891s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_15.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_16.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_016.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_016.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_016.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.640s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.406s.
# -- corrected illumination for channel 405 in 8.876s.
# - Finished illumination correction in 17.939s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_016.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 2.282s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.172s.
# -- corrected illumination for channel 488 in 2.187s.
# - Finished illumination correction in 5.015s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.06 -8.86  2.26] in 0.875s.
# -- drift 1: [-0.06 -8.81  2.34] in 0.891s.
# -- drift 2: [-0.05 -8.66  2.37] in 0.875s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.05666667 -8.77666667  2.32333333] for channel: 750
# -- finish warpping channel 750 in 23.876s.
# 488 False True
# -- warp image with drift:[-0.05666667 -8.77666667  2.32333333] for channel: 488
# -- finish warpping channel 488 in 24.514s.
# -- finish warpping in 48.391s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_16.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_17.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_017.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_017.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_017.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.125s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 11.031s.
# -- corrected illumination for channel 405 in 12.063s.
# - Finished illumination correction in 23.812s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_017.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.656s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 3.078s.
# -- corrected illumination for channel 488 in 3.422s.
# - Finished illumination correction in 6.891s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.01 -8.93  1.2 ] in 1.187s.
# -- drift 1: [ 0.   -8.67  1.21] in 1.065s.
# -- drift 2: [-0.02 -8.8   1.1 ] in 0.999s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-3.33333333e-03 -8.80000000e+00  1.17000000e+00] for channel: 750
# -- finish warpping channel 750 in 24.297s.
# 488 False True
# -- warp image with drift:[-3.33333333e-03 -8.80000000e+00  1.17000000e+00] for channel: 488
# -- finish warpping channel 488 in 24.766s.
# -- finish warpping in 49.063s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_17.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_18.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_018.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_018.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_018.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.828s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 12.140s.
# -- corrected illumination for channel 405 in 8.984s.
# - Finished illumination correction in 21.859s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_018.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 2.359s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.187s.
# -- corrected illumination for channel 488 in 2.156s.
# - Finished illumination correction in 4.969s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.04 -9.58  0.76] in 0.923s.
# -- drift 1: [-0.04 -9.65  0.65] in 0.905s.
# -- drift 2: [-0.09 -9.74  1.  ] in 0.907s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.05666667 -9.65666667  0.80333333] for channel: 750
# -- finish warpping channel 750 in 24.000s.
# 488 False True
# -- warp image with drift:[-0.05666667 -9.65666667  0.80333333] for channel: 488
# -- finish warpping channel 488 in 24.234s.
# -- finish warpping in 48.234s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_18.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_19.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_019.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_019.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_019.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.531s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 9.656s.
# -- corrected illumination for channel 405 in 8.551s.
# - Finished illumination correction in 18.646s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_019.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.181s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.086s.
# -- corrected illumination for channel 488 in 2.078s.
# - Finished illumination correction in 4.359s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.09 -9.73  0.16] in 0.844s.
# -- drift 1: [-0.08 -9.61  0.41] in 0.844s.
# -- drift 2: [-0.11 -9.43  0.14] in 0.859s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.09333333 -9.59        0.23666667] for channel: 750
# -- finish warpping channel 750 in 23.359s.
# 488 False True
# -- warp image with drift:[-0.09333333 -9.59        0.23666667] for channel: 488
# -- finish warpping channel 488 in 23.266s.
# -- finish warpping in 46.625s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_19.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_20.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_020.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_020.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_020.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 4.766s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.281s.
# -- corrected illumination for channel 405 in 8.328s.
# - Finished illumination correction in 16.827s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_020.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 0.812s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.094s.
# -- corrected illumination for channel 488 in 2.125s.
# - Finished illumination correction in 4.422s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.13 -7.51  0.92] in 0.844s.
# -- drift 1: [-0.17 -7.62  1.34] in 0.828s.
# -- drift 2: [-0.11 -7.07  0.77] in 0.875s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.13666667 -7.4         1.01      ] for channel: 750
# -- finish warpping channel 750 in 23.203s.
# 488 False True
# -- warp image with drift:[-0.13666667 -7.4         1.01      ] for channel: 488
# -- finish warpping channel 488 in 24.344s.
# -- finish warpping in 47.547s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_20.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_21.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_021.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_021.dax
# ...
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 9.608s.
# -- corrected illumination for channel 405 in 9.656s.
# - Finished illumination correction in 19.297s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_154.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.797s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.734s.
# -- corrected illumination for channel 488 in 2.641s.
# - Finished illumination correction in 5.422s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.04 -7.1  12.04] in 0.969s.
# -- drift 1: [-0.05 -7.12 12.32] in 1.000s.
# -- drift 2: [-0.06 -6.98 12.13] in 0.984s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.05       -7.06666667 12.16333333] for channel: 750
# -- finish warpping channel 750 in 23.656s.
# 488 False True
# -- warp image with drift:[-0.05       -7.06666667 12.16333333] for channel: 488
# -- finish warpping channel 488 in 23.219s.
# -- finish warpping in 46.875s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_154.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_155.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_155.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_155.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_155.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 6.547s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.709s.
# -- corrected illumination for channel 405 in 9.494s.
# - Finished illumination correction in 18.547s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_155.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.860s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.421s.
# -- corrected illumination for channel 488 in 2.485s.
# - Finished illumination correction in 5.313s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.04 -6.84  8.99] in 0.953s.
# -- drift 1: [-0.02 -6.73  9.1 ] in 0.938s.
# -- drift 2: [-0.04 -6.78  9.1 ] in 1.031s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.03333333 -6.78333333  9.06333333] for channel: 750
# -- finish warpping channel 750 in 24.203s.
# 488 False True
# -- warp image with drift:[-0.03333333 -6.78333333  9.06333333] for channel: 488
# -- finish warpping channel 488 in 23.578s.
# -- finish warpping in 47.781s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_155.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_156.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_156.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_156.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_156.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.271s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 10.326s.
# -- corrected illumination for channel 405 in 9.265s.
# - Finished illumination correction in 20.109s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_156.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.906s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.359s.
# -- corrected illumination for channel 488 in 2.421s.
# - Finished illumination correction in 5.187s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.06 -6.21  8.23] in 0.969s.
# -- drift 1: [-0.04 -5.97  8.31] in 1.046s.
# -- drift 2: [-0.04 -6.03  8.15] in 0.922s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.04666667 -6.07        8.23      ] for channel: 750
# -- finish warpping channel 750 in 24.063s.
# 488 False True
# -- warp image with drift:[-0.04666667 -6.07        8.23      ] for channel: 488
# -- finish warpping channel 488 in 24.453s.
# -- finish warpping in 48.516s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_156.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_157.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_157.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_157.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_157.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.266s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.172s.
# -- corrected illumination for channel 405 in 8.375s.
# - Finished illumination correction in 16.922s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_157.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.516s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.250s.
# -- corrected illumination for channel 488 in 2.250s.
# - Finished illumination correction in 5.109s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.31 -6.42  8.4 ] in 0.891s.
# -- drift 1: [-0.28 -6.29  8.6 ] in 0.922s.
# -- drift 2: [-0.3  -6.27  8.45] in 0.890s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.29666667 -6.32666667  8.48333333] for channel: 750
# -- finish warpping channel 750 in 24.266s.
# 488 False True
# -- warp image with drift:[-0.29666667 -6.32666667  8.48333333] for channel: 488
# -- finish warpping channel 488 in 24.766s.
# -- finish warpping in 49.031s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_157.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_158.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_158.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_158.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_158.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.406s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.172s.
# -- corrected illumination for channel 405 in 8.469s.
# - Finished illumination correction in 16.937s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_158.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.500s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.078s.
# -- corrected illumination for channel 488 in 2.179s.
# - Finished illumination correction in 4.663s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.16 -6.04  8.11] in 0.875s.
# -- drift 1: [-0.16 -5.76  8.38] in 0.875s.
# -- drift 2: [-0.16 -5.89  8.38] in 0.875s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[-0.16       -5.89666667  8.29      ] for channel: 750
# -- finish warpping channel 750 in 23.125s.
# 488 False True
# -- warp image with drift:[-0.16       -5.89666667  8.29      ] for channel: 488
# -- finish warpping channel 488 in 23.016s.
# -- finish warpping in 46.140s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_158.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_159.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_159.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_159.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_159.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.687s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 8.250s.
# -- corrected illumination for channel 405 in 9.719s.
# - Finished illumination correction in 18.453s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_159.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.766s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.672s.
# -- corrected illumination for channel 488 in 2.406s.
# - Finished illumination correction in 5.391s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.04 -6.41  8.93] in 0.937s.
# -- drift 1: [ 0.05 -6.2   8.97] in 0.953s.
# -- drift 2: [ 0.03 -6.28  8.96] in 0.859s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[ 0.04       -6.29666667  8.95333333] for channel: 750
# -- finish warpping channel 750 in 23.000s.
# 488 False True
# -- warp image with drift:[ 0.04       -6.29666667  8.95333333] for channel: 488
# -- finish warpping channel 488 in 23.102s.
# -- finish warpping in 46.103s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_159.npy
# - load seg file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\segmentation_label_160.npy
# \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_160.dax \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_160.dax
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H0M1\Conv_zscan_160.dax
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  50 2048 2048]
# - Loaded images for channels:['488', '405'] in 5.141s.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 11.109s.
# -- corrected illumination for channel 405 in 8.906s.
# - Finished illumination correction in 20.391s.
# Initialize DaxProcesser for file:\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\H11M12\Conv_zscan_160.dax
# -- all used channels: ['750', '647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['750', '488'] in 1.484s.
# - Start illumination correction for channels:['750', '488'].
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 750 in 2.094s.
# -- corrected illumination for channel 488 in 2.094s.
# - Finished illumination correction in 4.609s.
# + Calculate drift with drift_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ 3.000e-02 -5.750e+00 -3.467e+01] in 0.844s.
# -- drift 1: [  0.23  -5.44 -34.45] in 0.844s.
# -- drift 2: [ 3.000e-02 -5.700e+00 -3.461e+01] in 0.859s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images channels:['750', '488'].
# 750 False False
# -- warp image with drift:[  0.09666667  -5.63       -34.57666667] for channel: 750
# -- finish warpping channel 750 in 22.906s.
# 488 False True
# -- warp image with drift:[  0.09666667  -5.63       -34.57666667] for channel: 488
# -- finish warpping channel 488 in 23.203s.
# -- finish warpping in 46.109s.
# - save to file: \\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors\Segmentation\watershed\segmentation_label_160.npy

# %% [markdown]
# ## check output

# %%
visual_tools.imshow_mark_3d_v2([_ref_cls.im_405, polyt_im, corr_labels3d, new_labels])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">
